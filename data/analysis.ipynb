# %%
import pandas as pd
from IPython.display import display

# %%
data = pd.read_csv('COBRA-YTD2017.csv')

# %%
# df = data.groupby('crimetype')['MaxOfnum_victims'].nunique()

# result = data.apply(pd.value_counts).fillna(0)
# print(df.shape)

# print(df) # Shows which crime has the most victims and unique crime names.
# Out:
# C:\Users\kbantupa\Desktop\ml-project\venv\lib\site-packages\pandas\core\indexes\api.py:87: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\Users\kbantupa\Desktop\ml-project\venv\lib\site-packages\pandas\core\frame.py:6206: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes)

# %%
n_matches = data.shape[0]

n_features = data.shape[1] - 1

# %%
data.rename(columns = {'UC2 Literal' : 'crimetype'}, inplace=True)
# https://stackoverflow.com/questions/19758364/rename-a-single-column-header-in-a-pandas-dataframe
# display(data.head())


# n_larceny = len(data[data.crimetype == 'LARCENY-FROM VEHICLE'])

# n_robped = len(data[data.crimetype == 'ROBBERY-PEDESTRIAN'])

# n_burgres = len(data[data.crimetype == 'BURGLARY-RESIDENCE'])

# n_autotheft = len(data[data.crimetype == 'AUTO-THEFT'])

# n_burgnres = len(data[data.crimetype == 'BURGLARY-NONRES'])

# n_robres = len(data[data.crimetype == 'ROBBERY-RESIDENCE'])

# n_larcenyn = len(data[data.crimetype == 'LARCENY-NON VEHICLE'])

# n_aggass = len(data[data.crimetype == 'AGG ASSAULT'])

# n_rape = len(data[data.crimetype == 'RAPE'])

# n_robcom = len(data[data.crimetype == 'ROBBERY-COMMERCIAL'])

# n_homi = len(data[data.crimetype == 'HOMICIDE'])

# %%
larceny_rate = (float(n_larceny) / (n_matches)) * 100

# %%
print("Total number of matches :", n_matches)
print("Number of features :", n_features)
print("Number of times larceny from veh was commited :", n_larceny)
print("Larceny Rate :", larceny_rate)
# Out:
# Total number of matches : 26759
# Number of features : 22
# Number of times larceny from veh was commited : 9840
# Larceny Rate : 36.77267461414851

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(data[['MaxOfnum_victims', 'loc_type']], figsize=(10,10))
# Out:
# C:\Users\kbantupa\Desktop\ml-project\venv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020C90E0F160>,
# ...
#       dtype=object)
